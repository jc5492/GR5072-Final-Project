# %% [markdown]
# NYC open data has a vehicle crash dataset that contains over 1.8m records of accidents across the give boroughs.
#
# My package aims to build an easy function to connect to this API given certain parameters to extract whatever subset of this dataset needed. For example, the data could be filtered by time, date. borough, zipcodes and injuries/deaths.
#
# The package can be found at https://test.pypi.org/project/final-project-jc5492/

# %%
# !pip install -i https://test.pypi.org/pypi/ --extra-index-url https://pypi.org/simple final-project-jc5492
# Out:
# Looking in indexes: https://test.pypi.org/pypi/, https://pypi.org/simple
# Requirement already satisfied: final-project-jc5492 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (0.2.0)
# Requirement already satisfied: Sphinx<5.0.0,>=4.2.0 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from final-project-jc5492) (4.3.1)
# Requirement already satisfied: geocoder<2.0.0,>=1.38.1 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from final-project-jc5492) (1.38.1)
# Requirement already satisfied: pytest<7.0.0,>=6.2.5 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from final-project-jc5492) (6.2.5)
# Requirement already satisfied: pandas<2.0.0,>=1.3.5 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from final-project-jc5492) (1.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.26.0 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from final-project-jc5492) (2.26.0)
# Requirement already satisfied: six in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from geocoder<2.0.0,>=1.38.1->final-project-jc5492) (1.16.0)
# Requirement already satisfied: click in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from geocoder<2.0.0,>=1.38.1->final-project-jc5492) (8.0.3)
# Requirement already satisfied: ratelim in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from geocoder<2.0.0,>=1.38.1->final-project-jc5492) (0.1.6)
# Requirement already satisfied: future in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from geocoder<2.0.0,>=1.38.1->final-project-jc5492) (0.18.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pandas<2.0.0,>=1.3.5->final-project-jc5492) (2.8.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Jian Tong\AppData\Local\pypoetry\Cache\virtualenvs\final-project-jc5492-FmXodZ5A-py3.9\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pandas<2.0.0,>=1.3.5->final-project-jc5492) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pandas<2.0.0,>=1.3.5->final-project-jc5492) (2021.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pytest<7.0.0,>=6.2.5->final-project-jc5492) (21.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pytest<7.0.0,>=6.2.5->final-project-jc5492) (1.4.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pytest<7.0.0,>=6.2.5->final-project-jc5492) (1.0.0)
# Requirement already satisfied: toml in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pytest<7.0.0,>=6.2.5->final-project-jc5492) (0.10.2)
# Requirement already satisfied: py>=1.8.2 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pytest<7.0.0,>=6.2.5->final-project-jc5492) (1.11.0)
# Requirement already satisfied: packaging in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pytest<7.0.0,>=6.2.5->final-project-jc5492) (21.3)
# Requirement already satisfied: colorama in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pytest<7.0.0,>=6.2.5->final-project-jc5492) (0.4.4)
# Requirement already satisfied: iniconfig in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from pytest<7.0.0,>=6.2.5->final-project-jc5492) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from requests<3.0.0,>=2.26.0->final-project-jc5492) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from requests<3.0.0,>=2.26.0->final-project-jc5492) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from requests<3.0.0,>=2.26.0->final-project-jc5492) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from requests<3.0.0,>=2.26.0->final-project-jc5492) (2.0.9)
# Requirement already satisfied: docutils<0.18,>=0.14 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (0.17.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (0.7.12)
# Requirement already satisfied: babel>=1.3 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (2.9.1)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (1.0.3)
# Requirement already satisfied: imagesize in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (1.3.0)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (1.0.2)
# Requirement already satisfied: Jinja2>=2.3 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (3.0.3)
# Requirement already satisfied: Pygments>=2.0 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (2.10.0)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (1.0.2)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (2.0.0)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (2.2.0)
# Requirement already satisfied: setuptools in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (58.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from Jinja2>=2.3->Sphinx<5.0.0,>=4.2.0->final-project-jc5492) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from packaging->pytest<7.0.0,>=6.2.5->final-project-jc5492) (3.0.6)
# Requirement already satisfied: decorator in c:\users\jian tong\appdata\local\pypoetry\cache\virtualenvs\final-project-jc5492-fmxodz5a-py3.9\lib\site-packages (from ratelim->geocoder<2.0.0,>=1.38.1->final-project-jc5492) (5.1.0)

# %%
from final_project_jc5492 import final_project_jc5492 as final

# %%
help(final.get_crash_data)
# Out:
# Help on function get_crash_data in module final_project_jc5492.final_project_jc5492:
#
# get_crash_data(params={'limit': 10000})
#     Gets vehicle collision data from NYC open data API based on provided dictionary of parameters.
#
#     Parameters
#     ----------
#     date : String
#       Either a single date in "YYYY-MM-DD" format, or a list of [min date, max date]
#     time : String
#       Either a single time in "HH:MM" format, or a list of [min time, max time]
#     zip_code : Integer
#       Either a single 5 digit zip code, or a list of [min zip code, max zip code]
#     borough : String
#       List of boroughs to be included i.e. ["MANHATTAN","QUEENS","BRONX"]
#     injury : Integer
#       Either a single integer or a list of [min injuries, max injuries]
#     death : Integer
#       Either a single integer or a list of [min deaths, max deaths]
#     limit : Integer
#       Maximum number of rows to return from API
#
#     Returns
#     --------
#     Pandas DataFrame
#       DataFrame of vehicle collisions returned from API
#
#     Examples
#     --------
#     >>> default_params = {"date":['2021-01-01','2021-01-15'],
#             "time":["09:00","17:00" ],
#             "borough":["MANHATTAN"],
#             "injury":[0,10],
#             "death":[0,0],
#             "limit":10000}
#     >>> df = get_crash_data(default_params)

# %%
default_params = {"date":['2021-01-1','2021-01-15'],
          "time":["09:00","17:00" ],
          "borough":["MANHATTAN"],
          "injury":[0,10],
          "death":[0,0],
          "limit":10000}

# %%
df = final.get_crash_data(default_params)
df.head()
# Out:
#                 crash_date crash_time    borough zip_code    latitude  \
# 0  2021-01-01T00:00:00.000       1:02  MANHATTAN    10029  40.7874400
# 1  2021-01-01T00:00:00.000      16:25  MANHATTAN    10018  40.7595140
# 2  2021-01-01T00:00:00.000       1:12  MANHATTAN    10019  40.7632500
# 3  2021-01-01T00:00:00.000      16:40  MANHATTAN    10034  40.8644030
# 4  2021-01-02T00:00:00.000      11:37  MANHATTAN    10001  40.7528340
#
#      longitude                                           location  \
# 0  -73.9447800  {'latitude': '40.78744', 'longitude': '-73.944...
# 1  -73.9992600  {'latitude': '40.759514', 'longitude': '-73.99...
# 2  -73.9891360  {'latitude': '40.76325', 'longitude': '-73.989...
# 3  -73.9237750  {'latitude': '40.864403', 'longitude': '-73.92...
# 4  -74.0047150  {'latitude': '40.752834', 'longitude': '-74.00...
#
#                      on_street_name  off_street_name  \
# 0  2 AVENUE                          EAST 101 STREET
# 1  11 AVENUE                          WEST 40 STREET
# 2                               NaN              NaN
# 3  SHERMAN AVENUE                     ACADEMY STREET
# 4                               NaN              NaN
#
#   number_of_persons_injured  ...                   vehicle_type_code1  \
# 0                         2  ...                                 Taxi
# 1                         0  ...                                Sedan
# 2                         0  ...  Station Wagon/Sport Utility Vehicle
# 3                         0  ...  Station Wagon/Sport Utility Vehicle
# 4                         0  ...                                Sedan
#
#   contributing_factor_vehicle_2                         cross_street_name  \
# 0                           NaN                                       NaN
# 1                   Unspecified                                       NaN
# 2                   Unspecified  733       9 AVENUE
# 3                   Unspecified                                       NaN
# 4                           NaN  601       WEST 29 STREET
#
#   vehicle_type_code2 contributing_factor_vehicle_3 vehicle_type_code_3  \
# 0                NaN                           NaN                 NaN
# 1                NaN                           NaN                 NaN
# 2               Bike                           NaN                 NaN
# 3              Sedan                           NaN                 NaN
# 4                NaN                           NaN                 NaN
#
#   contributing_factor_vehicle_4 contributing_factor_vehicle_5  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   vehicle_type_code_4 vehicle_type_code_5
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# One problem with the dataset is that not every observation has a location provided in latitude and longitude. To work around this, I've created a function using the geocoder packager and OpenStreetMaps to obtain the latitude and longitude for these observataions based on the addresses found in "on_street_name", "off_street_name" and "cross_street_name"

# %%
#rows with missing long/lat
df[df['location'].isna()]
# Out:
#                  crash_date crash_time    borough zip_code latitude longitude  \
# 45  2021-01-07T00:00:00.000      10:44  MANHATTAN    10019      NaN       NaN
# 61  2021-01-08T00:00:00.000      15:00  MANHATTAN    10019      NaN       NaN
# 76  2021-01-10T00:00:00.000      11:35  MANHATTAN    10021      NaN       NaN
#
#    location                    on_street_name off_street_name  \
# 45      NaN  12 AVENUE                         WEST 51 STREET
# 61      NaN  WEST 56 STREET                         12 AVENUE
# 76      NaN  EAST 73 STREET                         FDR DRIVE
#
#    number_of_persons_injured  ...                   vehicle_type_code1  \
# 45                         1  ...  Station Wagon/Sport Utility Vehicle
# 61                         1  ...  Station Wagon/Sport Utility Vehicle
# 76                         0  ...                                Sedan
#
#    contributing_factor_vehicle_2 cross_street_name  \
# 45                   Unspecified               NaN
# 61                   Unspecified               NaN
# 76                   Unspecified               NaN
#
#                      vehicle_type_code2 contributing_factor_vehicle_3  \
# 45                                Sedan                           NaN
# 61  Station Wagon/Sport Utility Vehicle                           NaN
# 76  Station Wagon/Sport Utility Vehicle                           NaN
#
#    vehicle_type_code_3 contributing_factor_vehicle_4  \
# 45                 NaN                           NaN
# 61                 NaN                           NaN
# 76                 NaN                           NaN
#
#    contributing_factor_vehicle_5 vehicle_type_code_4 vehicle_type_code_5
# 45                           NaN                 NaN                 NaN
# 61                           NaN                 NaN                 NaN
# 76                           NaN                 NaN                 NaN
#
# [3 rows x 29 columns]

# %%
df[df['location'].isna()].apply(final.geocode_missing_row, axis = 1)
# Out:
# 45                  [42.63981715, -73.7768841]
# 61    [40.763741350000004, -73.97900946431503]
# 76                   [40.7881752, -73.9385601]
# dtype: object
